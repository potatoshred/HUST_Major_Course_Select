# %%
import requests
import time
import os

# %% [markdown]
# ### 手动更新

# %%
UA = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
Cookie = "xxxxxxxxxxxxxxxxxxx"

# %%
cookies = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,ja;q=0.6",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Cookie": Cookie,
    "Host": "wsxk.hust.edu.cn",
    "Pragma": "no-cache",
    "Referer": "",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": UA,
    "X-Requested-With": "XMLHttpRequest",
}
sess = requests.Session()

# %% [markdown]
# ### 课程信息 getXsFaFZkc

# %% [markdown]
# #### getXsFaFZkc
# {
#     "code": 0,
#     "data": [
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "计算理论",
#             "FZID": 5464,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1195,
#             "ZSXKMS": "0",
#             "XKRS": 39,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 1,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：计算理论",
#             "ZSXZFZS": "1",
#             "KCRL": 60,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w121560",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": "0700234",
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "数值分析",
#             "FZID": 5534,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1196,
#             "ZSXKMS": "0",
#             "XKRS": 35,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 2,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：数值分析",
#             "ZSXZFZS": "1",
#             "KCRL": 70,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "0735206",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "计算机图形学",
#             "FZID": 5466,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 1,
#             "ID": 1197,
#             "ZSXKMS": "0",
#             "XKRS": 120,
#             "TYPE": 1,
#             "YZ": [],
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 3,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：计算机图形学",
#             "ZSXZFZS": "1",
#             "KCRL": 120,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w121521",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "大数据管理概论",
#             "FZID": 5467,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 1,
#             "ID": 1198,
#             "ZSXKMS": "0",
#             "XKRS": 70,
#             "TYPE": 1,
#             "YZ": [],
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 4,
#             "KCZXF": 2.5,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：大数据管理概论",
#             "ZSXZFZS": "1",
#             "KCRL": 70,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w904716",
#             "KCZXS": 40
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "函数式编程原理",
#             "FZID": 5468,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 1,
#             "ID": 1199,
#             "ZSXKMS": "0",
#             "XKRS": 210,
#             "TYPE": 1,
#             "YZ": [],
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 5,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：函数式编程原理",
#             "ZSXZFZS": "1",
#             "KCRL": 210,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w121222",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "计算机视觉导论",
#             "FZID": 5469,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 1,
#             "ID": 1200,
#             "ZSXKMS": "0",
#             "XKRS": 210,
#             "TYPE": 1,
#             "YZ": [],
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 6,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：计算机视觉导论",
#             "ZSXZFZS": "1",
#             "KCRL": 210,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w906611",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "嵌入式系统",
#             "FZID": 5561,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1201,
#             "ZSXKMS": "0",
#             "XKRS": 120,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 7,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：嵌入式系统",
#             "ZSXZFZS": "1",
#             "KCRL": 120,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w122179",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "接口技术",
#             "FZID": 5519,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1202,
#             "ZSXKMS": "0",
#             "XKRS": 70,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 8,
#             "KCZXF": 3,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：接口技术",
#             "ZSXZFZS": "1",
#             "KCRL": 70,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w121673",
#             "KCZXS": 48
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "深度学习",
#             "FZID": 5533,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1203,
#             "ZSXKMS": "0",
#             "XKRS": 90,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 9,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：深度学习",
#             "ZSXZFZS": "1",
#             "KCRL": 90,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w904013",
#             "KCZXS": 32
#         },
#         {
#             "KCDM": null,
#             "FZXKFS": "2",
#             "FZMC": "按组内课程选分组01",
#             "KCMC": "大数据存储系统与管理",
#             "FZID": 5679,
#             "XKGZ": "1",
#             "ZSXKXF": null,
#             "SFYX": 0,
#             "ID": 1218,
#             "ZSXKMS": "0",
#             "XKRS": 60,
#             "TYPE": 0,
#             "YZ": null,
#             "XQMC": "2025年秋季",
#             "XQH": "20251",
#             "ZDXZFZS": "1",
#             "ROW_ID": 10,
#             "KCZXF": 2,
#             "ZDXKXF": null,
#             "FAMC": "2025年秋季计算机2023级：大数据存储系统与管理",
#             "ZSXZFZS": "1",
#             "KCRL": 60,
#             "XKXZFS": "1",
#             "ZDXKMS": "0",
#             "KCBH": "w127601",
#             "KCZXS": 32
#         }
#     ],
#     "count": 10
# }

# %%
cookies["Referer"] = "https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAkcxk?fzxkfs=&xkgz=1"
data = {
    "page": 1,
    "xkgz": 1, # 选课规则
    "limit": 10,
    "fzxkfs": "", # 分组选课方式
}

ls = []

tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getXsFaFZkc",
                headers=cookies, params=data).json()
for kc in tst['data']:
    kcmc, fzid, kcbh, faid, xqh = kc['KCMC'], kc['FZID'], kc['KCBH'], kc['ID'], kc['XQH']
    print(xqh, faid, kcmc, fzid, kcbh)
# Out:
# 20251 1195 计算理论 5464 w121560
# 20251 1196 数值分析 5534 0735206
# 20251 1197 计算机图形学 5466 w121521
# 20251 1198 大数据管理概论 5467 w904716
# 20251 1199 函数式编程原理 5468 w121222
# 20251 1200 计算机视觉导论 5469 w906611
# 20251 1201 嵌入式系统 5561 w122179
# 20251 1202 接口技术 5519 w121673
# 20251 1203 深度学习 5533 w904013
# 20251 1218 大数据存储系统与管理 5679 w127601

# %% [markdown]
# ### 课堂信息 getFzkt

# %% [markdown]
# #### getFzkt
# {
#     "code": "0",
#     "data": [
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "8-9周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179001",
#             "JSBH": "C12105005",
#             "XQH": "20251",
#             "PXZC": "8",
#             "ZXSS": 4,
#             "XM": "涂刚",
#             "XQ": "1",
#             "JC": "5-6节",
#             "DWBH": "210",
#             "JHID": 972378,
#             "KTMC": "计算机2023级课堂1：涂刚、张杰",
#             "JSMC": "西十二楼N505",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "XM": "涂刚",
#                 "SFID": "E200400196",
#                 "ZGH": "2004010196"
#             },
#             "TYPE": 0
#         },
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "8-9周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179001",
#             "JSBH": "C12105005",
#             "XQH": "20251",
#             "PXZC": "8",
#             "ZXSS": 4,
#             "XM": "涂刚",
#             "XQ": "3",
#             "JC": "5-6节",
#             "DWBH": "210",
#             "JHID": 972379,
#             "KTMC": "计算机2023级课堂1：涂刚、张杰",
#             "JSMC": "西十二楼N505",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "$ref": "$.data[0].KTFZR"
#             },
#             "TYPE": 0
#         },
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "12-17周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179001",
#             "JSBH": "N01008008",
#             "XQH": "20251",
#             "PXZC": "12",
#             "ZXSS": 4,
#             "XM": "涂刚",
#             "XQ": "1",
#             "JC": "9-12节",
#             "DWBH": "210",
#             "JHID": 972380,
#             "KTMC": "计算机2023级课堂1：涂刚、张杰",
#             "JSMC": "南一楼808_1",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "$ref": "$.data[0].KTFZR"
#             },
#             "TYPE": 0
#         },
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "8-9周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179002",
#             "JSBH": "C12005009",
#             "XQH": "20251",
#             "PXZC": "8",
#             "ZXSS": 4,
#             "XM": "周正勇",
#             "XQ": "1",
#             "JC": "5-6节",
#             "DWBH": "210",
#             "JHID": 972383,
#             "KTMC": "计算机2023级课堂2：周正勇、姚杰",
#             "JSMC": "西十二楼S509",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "XM": "周正勇",
#                 "SFID": "E200000096",
#                 "ZGH": "2000010096"
#             },
#             "TYPE": 0
#         },
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "8-9周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179002",
#             "JSBH": "C12005009",
#             "XQH": "20251",
#             "PXZC": "8",
#             "ZXSS": 4,
#             "XM": "周正勇",
#             "XQ": "3",
#             "JC": "5-6节",
#             "DWBH": "210",
#             "JHID": 972384,
#             "KTMC": "计算机2023级课堂2：周正勇、姚杰",
#             "JSMC": "西十二楼S509",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "$ref": "$.data[3].KTFZR"
#             },
#             "TYPE": 0
#         },
#         {
#             "KTRL": 60,
#             "SFKTFZR": 1,
#             "CJLRYX": "210",
#             "SFID": "U202315696",
#             "ZC": "12-17周",
#             "KTRS": 60,
#             "DWMC": "计算机科学与技术学院",
#             "KTBH": "20251w122179002",
#             "JSBH": "N01008008",
#             "XQH": "20251",
#             "PXZC": "12",
#             "ZXSS": 4,
#             "XM": "周正勇",
#             "XQ": "4",
#             "JC": "9-12节",
#             "DWBH": "210",
#             "JHID": 972385,
#             "KTMC": "计算机2023级课堂2：周正勇、姚杰",
#             "JSMC": "南一楼808_1",
#             "KCBH": "w122179",
#             "KTFZR": {
#                 "$ref": "$.data[3].KTFZR"
#             },
#             "TYPE": 0
#         }
#     ],
#     "count": 0
# }

# %%
cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
data = {
    "page": 1,
    "limit": 10,
    "fzid": fzid, # 分组ID
    "kcbh": kcbh, # 课程编号
    "sfid": "",
    "faid": faid, # 方案ID
    "id": faid,
}
tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getFzkt",
                headers=cookies, params=data).json()
s = set()
for kt in tst['data']:
    ktbh = kt['KTBH']
    s.add((kt['XM'], kt['KTBH'], kt['KTRS'], kt['KTRL'])) # 姓名，课堂编号，课堂人数，课堂容量
print(s)
# Out:
# {('华宇', '20251w127601001', 60, 60), ('施展', '20251w127601001', 60, 60)}

# %% [markdown]
# ### 选课

# %%
cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
data = {
    "kcbh": kcbh,
    "ktbh": ktbh, # 课堂编号
    "fzid": fzid,
    "sfid": "",
    "faid": faid,
    "xqh": xqh, # 学期号
}
tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/addStuxkIsxphx",
                headers=cookies, params=data).json()
tst
# Out:
# {'msg': '选择的课堂容量已满,请选择其他课堂!', 'code': '1'}

# %% [markdown]
# # 一键选课

# %%
Cookie = ""

# %%
import requests

UA = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
cookies = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,ja;q=0.6",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Cookie": Cookie,
    "Host": "wsxk.hust.edu.cn",
    "Pragma": "no-cache",
    "Referer": "",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": UA,
    "X-Requested-With": "XMLHttpRequest",
}
sess = requests.Session()

def post_select(kcbh, ktbh, fzid, faid, xqh, kcmc, jsxm):
    try:
        cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
        data = {
            "kcbh": kcbh,
            "ktbh": ktbh, # 课堂编号
            "fzid": fzid,
            "sfid": "",
            "faid": faid,
            "xqh": xqh, # 学期号
        }
        tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/addStuxkIsxphx", headers=cookies, params=data).json()
        print(kcmc, jsxm, tst)
    except:
        print(kcmc, jsxm, "FAIL")

# %% [markdown]
# # 根据实时结果选课

# %%
cookies["Referer"] = "https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAkcxk?fzxkfs=&xkgz=1"
data = {
    "page": 1,
    "xkgz": 1, # 选课规则
    "limit": 10,
    "fzxkfs": "", # 分组选课方式
}

ls = []

tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getXsFaFZkc",
                headers=cookies, params=data).json()
for kc in tst['data']:
    kcmc, fzid, kcbh, faid, xqh = kc['KCMC'], kc['FZID'], kc['KCBH'], kc['ID'], kc['XQH']
    print(xqh, faid, kcmc, fzid, kcbh)

    cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
    data = {
        "page": 1,
        "limit": 10,
        "fzid": fzid, # 分组ID
        "kcbh": kcbh, # 课程编号
        "sfid": "",
        "faid": faid, # 方案ID
        "id": faid,
    }
    tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getFzkt",
                    headers=cookies, params=data).json()
    for kt in tst['data']:
        ktbh = kt['KTBH'] # 课堂编号
        jsxm = kt['XM']   # 教师姓名
        ls.append((xqh, faid, fzid, kcbh, ktbh, kcmc, jsxm))

for i in range(len(ls)):
    print(i,":" *ls[i])

# %%
# 根据以上输出，选择对应序号
select_idx = [0, 1, 5, 8]
for i in select_idx:
    xqh, faid, fzid, kcbh, ktbh, kcmc, jsxm = ls[i]
    post_select(kcbh, ktbh, fzid, faid, xqh, kcmc, jsxm)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 select_idx = [0, 1, 5, 8]
#       3 for i in select_idx:
# ----> 4     xqh, faid, fzid, kcbh, ktbh, kcmc, jsxm = ls[i]
#       5     cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
#       6     data = {
#       7         "kcbh": kcbh,
#       8         "ktbh": ktbh, # 课堂编号
#    (...)
#      12         "xqh": xqh, # 学期号
#      13     }
#
# IndexError: list index out of range

# %% [markdown]
# # 根据课程信息选课

# %%
cookies["Referer"] = "https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAkcxk?fzxkfs=&xkgz=1"
data = {
    "page": 1,
    "xkgz": 1, # 选课规则
    "limit": 10,
    "fzxkfs": "", # 分组选课方式
}

select_course = [
    ("大数据管理概论", "左琼"),
    ("函数式编程原理", "郑然"),
    ("计算机图形学", "何云峰"),
    ("计算机视觉导论", "刘康"),
]

tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getXsFaFZkc",
                headers=cookies, params=data).json()
for kc in tst['data']:
    kcmc, fzid, kcbh, faid, xqh = kc['KCMC'], kc['FZID'], kc['KCBH'], kc['ID'], kc['XQH']
    print(xqh, faid, kcmc, fzid, kcbh)

    cookies["Referer"] = f"https://wsxk.hust.edu.cn/zyxxk/Stuxk/jumpAktxk?fzid={fzid}&kcbh={kcbh}&faid={faid}&sfid="
    data = {
        "page": 1,
        "limit": 10,
        "fzid": fzid, # 分组ID
        "kcbh": kcbh, # 课程编号
        "sfid": "",
        "faid": faid, # 方案ID
        "id": faid,
    }
    tst = sess.post("https://wsxk.hust.edu.cn/zyxxk/Stuxk/getFzkt",
                    headers=cookies, params=data).json()
    for kt in tst['data']:
        ktbh = kt['KTBH'] # 课堂编号
        jsxm = kt['XM']   # 教师姓名
        if (kcmc, jsxm) in select_course:
            post_select(kcbh, ktbh, fzid, faid, xqh, kcmc, jsxm)
# Out:
# 20251 1195 计算理论 5464 w121560
# 20251 1196 数值分析 5534 0735206
# 20251 1197 计算机图形学 5466 w121521
# 计算机图形学 何云峰 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 计算机图形学 何云峰 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 计算机图形学 何云峰 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 20251 1198 大数据管理概论 5467 w904716
# 大数据管理概论 左琼 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 大数据管理概论 左琼 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 大数据管理概论 左琼 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 20251 1199 函数式编程原理 5468 w121222
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 函数式编程原理 郑然 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 20251 1200 计算机视觉导论 5469 w906611
# 计算机视觉导论 刘康 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 计算机视觉导论 刘康 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 计算机视觉导论 刘康 {'msg': '当前学期或之前学期已选该课程，不可重复选择，可在‘选课记录’中查看！', 'code': '1'}
# 20251 1201 嵌入式系统 5561 w122179
# 20251 1202 接口技术 5519 w121673
# 20251 1203 深度学习 5533 w904013
# 20251 1218 大数据存储系统与管理 5679 w127601
